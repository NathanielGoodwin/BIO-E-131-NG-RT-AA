# %%
import matplotlib
import matplotlib.pyplot as plt
from Bio import Phylo

def plot_tree(tree_name):
    tree = Phylo.read(tree_name, "newick")
    matplotlib.rc('font', size=12)
    fig = plt.figure(figsize=(20, 20), dpi=100)
    axes = fig.add_subplot(1, 1, 1)
    Phylo.draw(tree, axes=axes)

    return

plot_tree("tree.nwk")

# %%
from Bio import SeqIO 
from Bio.Seq import Seq

records = list(SeqIO.parse( "seqs.fa", "fasta")) 
records_dict = SeqIO.to_dict(records)

#Cluster 1 Representative is hu.46 
print("Sequence of Cluster 1 Representative hu.46:") 
print(records_dict["hu.46"].seq) 
print("")

#Cluster 2 Representative is rh.40 
print("Sequence of Cluster 2 Representative rh.40:") 
print(records_dict["rh.40"].seq) 
print("")

#Cluster 3 Representative is rh.51 
print("Sequence of Cluster Representative rh.51:") 
print(records_dict["rh.51"].seq)
# Out:
# Sequence of Cluster 1 Representative hu.46:
# ...
#
# Sequence of Cluster 2 Representative rh.40:
# ...
#
# Sequence of Cluster Representative rh.51:
# ...
